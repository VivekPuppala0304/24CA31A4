# %% [markdown]
# ### Exercise(1) :- Text Cleaning - Removing unwanted characters and Normalizing text

# %% [markdown]
# ### AIM(1):
#
# ### To perform text cleaning by removing unwanted characters and normalizing text

# %% [markdown]
# ### Objective
#
# ### Apply basic text cleaning techniques on a given corpus.
#
#     1. <p> Data Science is AMAZING!!! Visit https://datascience.com</p>
#
#     2. Python 3.12 is released in 2025.
#
#     3. NLP is used in AI.
#
#     4. Contact us at info@gmail.com
#
# ### Expected Output
#
#     1. data science is amazing visit
#
#     2. python is released in
#
#     3. nlp is used in ai
#
#     4. contact us at

# %% [markdown]
# ### Pre-Lab Task:-

# %% [markdown]
# ### 1. Define Text Cleaning:
#                           Text is also a type of data used in NLP and Text analysis, but as the raw text contains many unwanted characters and noise which effects the model. So we use "TEXT CLEANING" - a process used to detect and remove unwanted elements (special characters,symbols,and punctuation marks etc..) as they hold no meaning in analysis and simplifies the data into a structred format.

# %% [markdown]
# ### 2.Write the method used to remove the following:
#     1. HTML tags :
#                     import re
#                     cleaned_text = re.sub(r'<.*?>', '', text)
#
#     2. URL's :
#                     cleaned_text = re.sub(r'https?://\S+|www\.\S+,'',text)
#
#     3. Email Addresses:
#                     cleaned_text = re.sub(r'\b[\w.-]+@[\w.-]+\.\w+\b', '', text)
#
#     4. Digits :
#                     cleaned_text = re.sub(r'\d+', '', text)
#
#     5. Extra spaces:
#                     cleaned_text = re.sub(r'\s+', ' ', text).strip()
#
#     6. Uppercase letters (Converted to lowercase):
#                     cleaned_text = text.lower()
#
#
# ANS:-
#         AS these are in text we can use Text cleaning with the help of Python manipulation.From python we can utilize many libraries like REGEX or from using direct python functions.

# %% [markdown]
# ### 3.What is the purpose of regular expressions?
#
# A Regular Expression (Regex) is a sequence of characters that defines a search pattern. It is mainly used to find, match, validate, extract, or replace text in strings.

# %% [markdown]
# ### 4. Which Python library is used to remove HTML tags?
#
# The best Python library which is used to remove HTML Tags is "BeautifulSoup(bs4)"
# Designed for parsing HTML/XML documents and removes HTML tags and converts them into plain text.

# %% [markdown]
# ### 5. What is the difference between \d+  and  \w+ in regular expressions?
#
# \d+ matches one or more digits (0–9). \d+ is used only for digits.
#
# \w+ matches one or more non-word characters (Excluding letters, digits, and underscores (_)) . That is every special characters, spaces, etc..

# %% [markdown]
# ### In- Lab Task
#
# ### Tasks
#
#     1. Create a Python list containing the given text corpus.
#     2. Import the required libraries (re and BeautifulSoup).
#     3. Convert all text to lowercase.
#     4. Remove HTML tags.
#     5. Remove URLs.
#     6. Remove email addresses.
#     7. Remove digits.
#     8. Remove punctuation and special characters.
#     9. Remove extra white spaces.
#     10. Store the cleaned text in a new list named cleaned_corpus.
#     11. Display the original corpus and the cleaned corpus.
#     12. Compare the text before and after cleaning.

# %% [markdown]
# ### LET'S DO THE CODE LIKE STEP FORMAT

# %%
# CREATE A PYTHON LIST CONTAINING THE GIVEN TEXT CORPUS

corpus = [

    "<p>Data Science is AMAZING!!! visit https://datascience.com</p>",
    "Python 3.12 is released in 2025.",
    "NLP is used in AI.",
    "Contact us at info@gmail.com"
]

# %%
#IMPORT THE REQUIRED LIBRARIES (re and BeautifulSoup)
import re
from bs4 import BeautifulSoup

# %%
# CONVERT ALL TEXT TO LOWER CASE

for text in corpus:
    text = text.lower()
    print(text)
# Out:
# <p>data science is amazing!!! visit https://datascience.com</p>
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com

# %%
lowercase_corpus = [text.lower() for text in corpus]
print(lowercase_corpus)
# Out:
# ['<p>data science is amazing!!! visit https://datascience.com</p>', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at info@gmail.com']

# %%
# REMOVE HTML TAGS

html_removed = [
    BeautifulSoup(text, "html.parser").get_text()
    for text in lowercase_corpus
]
print(html_removed)
# Out:
# ['data science is amazing!!! visit https://datascience.com', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at info@gmail.com']

# %%
# REMOVE URL'S

url_removed = [
    re.sub(r'https?://\S+',"",text)
    for text in html_removed
]
print(url_removed)
# Out:
# ['data science is amazing!!! visit ', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at info@gmail.com']

# %%
# REMOVE EMAIL ADDRESSES

email_removed = [
    re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b','',text)
    for text in url_removed
]
print(email_removed)
# Out:
# ['data science is amazing!!! visit ', 'python 3.12 is released in 2025.', 'nlp is used in ai.', 'contact us at ']

# %%
# REMOVE DIGITS.

digit_removed = [
    re.sub(r'\d+','', text)
    for text in email_removed
]
print(digit_removed)
# Out:
# ['data science is amazing!!! visit ', 'python . is released in .', 'nlp is used in ai.', 'contact us at ']

# %%
# REMOVE PUNCTUATION AND SPECIAL CHARACTER.

punct_removed = [
    re.sub(r'\W+',' ', text)
    for text in digit_removed
]
print(punct_removed)
# Out:
# ['data science is amazing visit ', 'python is released in ', 'nlp is used in ai ', 'contact us at ']

# %%
# REMOVE EXTRA WHITE SPACES

cleaned_corpus = [
    re.sub(r'\s+',' ',text).strip()
    for text in punct_removed
]
print(cleaned_corpus)
# Out:
# ['data science is amazing visit', 'python is released in', 'nlp is used in ai', 'contact us at']

# %%
# STORE THE CLEANED TEXT IN A NEW LIST NAMED cleaned_corpus

print("The cleaned text has been stored in the list 'cleaned_corpus'.")
print(cleaned_corpus)
# Out:
# The cleaned text has been stored in the list 'cleaned_corpus'.
# ['data science is amazing visit', 'python is released in', 'nlp is used in ai', 'contact us at']

# %%
# DISPLAY THE ORIGINAL CORPUS AND THE CLEANED CORPUS

print("Original Corpus:\n")
for sentence in corpus:
    print(sentence)

print("\nCleaned Corpus:\n")
for sentence in cleaned_corpus:
    print(sentence)
# Out:
# Original Corpus:
#
# <p>Data Science is AMAZING!!! visit https://datascience.com</p>
# Python 3.12 is released in 2025.
# NLP is used in AI.
# Contact us at info@gmail.com
#
# Cleaned Corpus:
#
# data science is amazing visit
# python is released in
# nlp is used in ai
# contact us at

# %%
# COMPARE THE TEXT BEFORE AND AFTER CLEANING

print("Comparison Before and After Cleaning:\n")

for original,cleaned in zip(corpus,cleaned_corpus):
    print("Original :",original)
    print("Cleaned :", cleaned)
    print("-"*60)
# Out:
# Comparison Before and After Cleaning:
#
# Original : <p>Data Science is AMAZING!!! visit https://datascience.com</p>
# Cleaned : data science is amazing visit
# ------------------------------------------------------------
# Original : Python 3.12 is released in 2025.
# Cleaned : python is released in
# ------------------------------------------------------------
# Original : NLP is used in AI.
# Cleaned : nlp is used in ai
# ------------------------------------------------------------
# Original : Contact us at info@gmail.com
# Cleaned : contact us at
# ------------------------------------------------------------

# %%
# FULL CODE WITHOUT STEP BY STEP

corpus = [
    "<p>Data Science is AMAZING!!! Visit https://datascience.com</p>",
    "Python 3.12 is released in 2025.",
    "NLP is used in AI.",
    "Contact us at info@gmail.com"
]

import re
from bs4 import BeautifulSoup

lowercase_corpus = [
    text.lower()
    for text in corpus
]

print("="*70)
print("Step 3: Lowercase Conversion")
print("="*70)

for text in lowercase_corpus:
    print(text)

html_removed = [
    BeautifulSoup(text,"html.parser").get_text()
    for text in lowercase_corpus
]    

print("\n"+"="*70)
print("Step 4: HTML Tags Removed")
print("="*70)

for text in html_removed:
    print(text)

url_removed = [
    re.sub(r'https?://\S+|www\.\S+',' ',text)
    for text in html_removed
]  

print("\n"+"="*70)
print("Step 5: URL'S Removed")
print("="*70)

for text in url_removed:
    print(text)

email_removed = [
    re.sub(r'b[\w\.-]+@[\w\.-]+\.\w+\b',' ',text)
    for text in url_removed
]    

print("\n" + "=" * 70)
print("Step 6: Email Addresses Removed")
print("=" * 70)

for text in email_removed:
    print(text)


digit_removed = [
    re.sub(r'\d+',' ',text)
    for text in email_removed
]
print("\n" + "=" * 70)
print("Step 7: Digits Removed")
print("=" * 70)

for text in digit_removed:
    print(text)


punct_Removed = [
    re.sub(r'\W+',' ',text)
    for text in digit_removed
]
print("\n" + "=" * 70)
print("Step 8: Punctuation and Special Characters are Removed")
print("=" * 70)

for text in punct_removed:
    print(text)

cleaned_corpus = [
    re.sub(r'\s+',' ',text).strip()
    for text in punct_removed
]    
print("\n" + "=" * 70)
print("Step 9: Extra White Spaces Removed")
print("=" * 70)

for text in cleaned_corpus:
    print(text)


print("\n" + "=" * 70)
print("Step 10: Cleaned Corpus Stored Successfully!")
print("=" * 70)

print(cleaned_corpus)

print("\n" + "=" * 70)
print("Original Corpus")
print("=" * 70)

for sentence in corpus:
    print(sentence)

print("\n" + "=" * 70)
print("Cleaned Corpus")
print("=" * 70)

for sentence in cleaned_corpus:
    print(sentence)

print("\n" + "=" * 70)
print("Comparison: Original Corpus  V/S  Cleaned Corpus")
print("=" * 70)

for original,cleaned in zip(corpus,cleaned_corpus):

    print("Original:", original)
    print("Cleaned :", cleaned)
    print("-"*70)
# Out:
# ...
# Step 3: Lowercase Conversion
# ...
# <p>data science is amazing!!! visit https://datascience.com</p>
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 4: HTML Tags Removed
# ...
# data science is amazing!!! visit https://datascience.com
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 5: URL'S Removed
# ...
# data science is amazing!!! visit
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 6: Email Addresses Removed
# ...
# data science is amazing!!! visit
# python 3.12 is released in 2025.
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 7: Digits Removed
# ...
# data science is amazing!!! visit
# python  .  is released in  .
# nlp is used in ai.
# contact us at info@gmail.com
#
# ...
# Step 8: Punctuation and Special Characters are Removed
# ...
# data science is amazing visit
# python is released in
# nlp is used in ai
# contact us at
#
# ...

# %% [markdown]
# THIS IS ABOUT HOW WE CAN CLEAN THE DATA FOR DIFFERENT TYPES OF ANAMOLIES

# %% [markdown]
# ### POST LAB:
#
# #### Collect five reviews from an online shopping website or social media platform.
# #### Apply the text cleaning techniques learned in this experiment and compare the original and cleaned text.
# #### Write a brief report (100–150 words) explaining the impact of text cleaning on the dataset

# %% [markdown]
# ##### FROM THE QUESTION WE HAVE TO IDENTIFY WHAT THE CLIENT WANTS FROM US
#
# ## Objectives
# ##### Collect five customer reviews.
# ##### Apply text cleaning techniques.
# ##### Compare the original and cleaned reviews.
# ##### Analyze the impact of text cleaning.

# %%
# TAKE OUR OWN DATA SET

reviews = [
    "My mans got eyes in the back of his head 👀 #restaurant #foodies #fypage #viralvideos",
    "Lots of Protein 🍔🥩 Contact denntt@meatshop.com",
    "Visit https://www.facebook.com/groups/1019064455361281/?ref=share&mibextid=NSMWBT",
    "fly high and rise ⭐  #studyreels #fypシ゚viralシ #studymotivation",
    "Wei Jiang W8606 Black Apple 🛒 Buy here 👉https://s.click.aliexpress.com/e/_c3HC0c4L 🤖 Transformers "
    
]

print("Original Reviews:\n")

for review in reviews:
    print(review)
# Out:
# Original Reviews:
#
# My mans got eyes in the back of his head 👀 #restaurant #foodies #fypage #viralvideos
# Lots of Protein 🍔🥩 Contact denntt@meatshop.com
# Visit https://www.facebook.com/groups/1019064455361281/?ref=share&mibextid=NSMWBT
# fly high and rise ⭐  #studyreels #fypシ゚viralシ #studymotivation
# Wei Jiang W8606 Black Apple 🛒 Buy here 👉https://s.click.aliexpress.com/e/_c3HC0c4L 🤖 Transformers

# %%
# IMPORT LIBRARIES

import re
from bs4 import BeautifulSoup

# %%
# CLEAN THE DATA/ REVIEWS
cleaned_reviews =[]

for review in reviews:

    # convert to lower case
    review = review.lower()

    # Remove HTML Tags
    review =  BeautifulSoup(review,"html.parser").get_text()

    #Remove URL'S
    review = re.sub(r'https?://\S+|www\.\S+',' ',review)

    #Remove EMAIL ADDRESS
    review = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b',' ', review)

    #Remove digits
    review = re.sub(r'\d+',' ', review)

    #Remove Punctuation and Special Characters
    review = re.sub(r'\W+',' ',review)

    #Remove Extra Spaces
    review = re.sub(r'\s+',' ',review).strip()

    cleaned_reviews.append(review)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_25916\970779009.py:10: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   review =  BeautifulSoup(review,"html.parser").get_text()

# %%
# COMPARE BEFORE AND AFTE CLEANING

print("Comparing of Original and Cleaned Reviews:\n")

for original,cleaned in zip(reviews,cleaned_reviews):

    print("Original Review:")
    print(original)

    print("\nCleaned Review:")
    print(cleaned)

    print("-"*80)
# Out:
# Comparing of Original and Cleaned Reviews:
#
# Original Review:
# My mans got eyes in the back of his head 👀 #restaurant #foodies #fypage #viralvideos
#
# Cleaned Review:
# my mans got eyes in the back of his head restaurant foodies fypage viralvideos
# --------------------------------------------------------------------------------
# Original Review:
# Lots of Protein 🍔🥩 Contact denntt@meatshop.com
#
# Cleaned Review:
# lots of protein contact
# --------------------------------------------------------------------------------
# Original Review:
# Visit https://www.facebook.com/groups/1019064455361281/?ref=share&mibextid=NSMWBT
#
# Cleaned Review:
# visit
# --------------------------------------------------------------------------------
# Original Review:
# fly high and rise ⭐  #studyreels #fypシ゚viralシ #studymotivation
#
# Cleaned Review:
# fly high and rise studyreels fypシ viralシ studymotivation
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## REPORT ON THIS LAB

# %% [markdown]
# <p align ="justify">Raw Text contains many of irrevelent elements which may effect the required output for the model.So, we have to preprocess the data with "TEXT CLEANING". Text Cleaning is an required preprocessing in NLP. In this phase,We can make use of "Text Cleaning" to identify and remove unwanted elements gathered from reviews like (special characters, symbols, HTML Tags, URL'S, and punctuation marks etc..) as they hold no meaning in analysis and simplifies the data into a structred format.
#
# By doing the TEXT CLEANING process we get the structured and proper data which is used as a proper data set for the model. Those data in NLP can be used for Sentiment Analysis,Text Classification, and Keyword Extraction.
#
# Text Cleaning process eleminates the noises and make dataset useful for models, and it also improves the performance of ML Algorithms and ML Models
